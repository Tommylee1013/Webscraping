# %% [markdown]
# ### Web data collection basics

# %% [markdown]
# #### Web basic terms
#
# **◆ Client and server**
#
# A client / server represents a role relationship between two computer programs.
# A client is a program that requests a service from another program, and a server is a program that responds to the request. In the case of the Internet, for example, a web browser is a client program that requests the transmission of a web page or file to a web server located somewhere on the internet.
#
# **◆ Web browser**
#
# Software for using Internet World Wide Web services. It supports HTTP, the protocol of the World Wide Web, and can open and display HTML documents. Originally, the term browser refers to user software used to search for information, but in most cases, a browser means a web browser to use the Internet World Wide Web. (Example : Google Chrome)
#
# **◆ URL (Universal Resource Locator)**
#
# Addresses of data (files) uploaded on the Internet . The address contains 3 elements.
# The first is the protocol type used to access files such as HTTP for web pages and FTP for sites.
# The second is the domain name or IP address of the server where the file is located.
# The last element is the pathname of the file indicating the location of the file.
# For example, for 'URL http://www.britannica.co.kr/world', the browser uses the HTTP protocol, moves to the web server 'www.britannica.co.kr', and accesses the file name 'world'. indicates that.
#
# **◆ Parsing**
#
# The process of decomposing a sentence into its syntactic elements.
# Parsing a string and splitting it into a family of elements that can be handled more easily the syntactic structure of a string.
# A program that can determine is called a parser. Every compiler or interpreter includes parser.
#
# **◆ Scraping**
#
# Extracting the necessary information from each page . Programs that do scraping are called scrapers. Ex) Extracting stock data from Naver Finance
#
# **◆ Crawler**
#
# A program that automatically repeats information collection
# Example ) A program that has the function of automatically taking pages of several items in turn, rather than extracting only one individual item.

# %% [markdown]
# **DOM-based web data collection**
# - DOM (Documents Object Model) Parsing
# By using the web browsers, programs can retrieve the dynamic content generated by client-side
# scripts. It is also possible to parse web pages (HTML, XML,...) into a D O M tree, based on which programs can retrieve parts of these pages.
# $\rightarrow$ web top various Resources for optionally collection will do number has exist
#
# - Open API (Application Programming Interface)
# Facebook, Twitter, LinkedIn , etc. provides public and/ or private APIs which can be called using standard code f or retrieving the datain the prescribed format.
# $\rightarrow$ beforehand decided data only to collect number has exist

# %% [markdown]
# #### Web document types
#
# ◆ HTML (Hyper Text Markup Language)
#
# Data exchange between a client program (with Internet Explorer) and a server program on the web network program. A markup- based (expressed in tags) language
#
# ◆ XML
#
# XML has a structure similar to HTML, but HTML uses a fixed tag name, while XML creates nodes arbitrarily and uses them as tags
#
# ◆ RSS
#
# It is made based on XML and can be parsed simpler than HTML. the website provides RSS , the webpage Links to RSS included. Ex) Meteorological
#
# ◆ CSS
#
# HTML _ document style by definition HTML the elements on screen output shape decision CSS separates the content and style of a web page, making it easy to apply and change styles. In an external CSS file, and changes to this file change the style of all web pages to which the style is applied.
#
# ◆ JSON
#
# A data format designed for data storage and exchange, with roots in the JavaScript programming language.
# Stored as key - value pairs

# %% [markdown]
# #### HTML text
#
# | Division   | tag and property                                                                                                                                                             |
# |------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Heading    | \<h1\>, \<h2\>,... ,\<h6\>: Largest heading, second largest heading, etc. letter size                                                                                        |
# | Paragraph  | \<p\>: Paragraph elements                                                                                                                                                    |
# | Formatting | \<b\>: bold, \<strong\>: bold, \<i\>: italic, \<em\>: italic, \<del\>: delete, \<ins\> insert,<br> \<mark\>: highlight, \<small\>: small letter, \<sub\>: 아랫첨자, \<sup\>: 윗첨자 |
# | List       | \<ul\>: Unordered bulleted list, \<ol\>: Ordered list, \<li\>: Individual List item                                                                                          |
# | Group      | \<div\>: Division or section (multiple other elements grouping), <br> \<span\>: Element middle part contents only separately grouping                                        |
# | table      | \<table\>: row defined as \<tr\> , title defined as \<th\> , cell value as \<td\> Justice                                                                                    |
# | Link       |\<a\>: click and move linked text or image box.|
# | Form       |\<form\>: defines a form . Sending data to the server through a form relay, <br> \<input\>: collect data from user , such as \<select\> \<textarea\> function <br> \<option\>: \<select\> within user to choose number there is of items List Justice|

# %% [markdown]
# #### CSS
#
# - Cascading Styles (CSS) Sheet)
#     - HTML 's document style by definition HTML the elements on screen output shape decision - CSS makes it easy to apply and change styles by separating the content and style
#     - Styles are usually stored in an external CSS file ( css extension ) , and the style can be changed by changing this file.
#     - Change the style of any web page you apply is possible
#
# ◆ With selectors and declaration blocks ( property names and property values ) composition
#
# 1. the selector It is used to find HTML elements, and the element name (HTML tag name ), id , or class is used as a selector.
#     1) element name selectors : specific HTML tag name
#     2) Id Selector: Selects elements with a specific id attribute. Append # before the element's id attribute name
#     1) Class Selector: Specific class properties having element selection. Attach . before the elements class property name
# 2. Element selector and class selector together using specific element only appointed possible
# Ex) \< p calss =“ center large”\>This is center and large.\</p\> # p and class: elements selector
# 3. Group using elements of the same style possible
#
# ◆ Xpath and CSS Selectors
#
# |CSS selector|X path| detail                                                             |
# |---|---|--------------------------------------------------------------------|
# |title|//title| All \<title\> nodes select                                         |
# |div i|//div/i| below the \<div\> node \<i\>                                       |
# |p>i|//p/i| \<i\> immediately below the \<p\> node select                      |
# |div[genre=“drama”]|//div[ @ genre=“drama”]| genre ( attribute ) value \<div\> node with drama ( value ) select |
#
# ◆ Nodes using CSS selectors select
#
# |selector| detail                                                                         |
# |---|--------------------------------------------------------------------------------|
# |*| all nodes select                                                               |
# |name| Node with node name name select                                                |
# |.class1| Nodes with class="class1" select                                               |
# |#id1| Node with id="id1" select                                                      |
# |[attr]| Select nodes with                                                              |
# |[attr=“value”]| A node whose attribute name is attr and whose attribute value is value1 select |
# |:nth-child(n)| $n$th child node select                                                        |
#
# ◆ Combining
#
# |combine <br> selectors structure|detail|
# |---|---|
# |AB|Among the descendant nodes of the node matched with A, the node matched with B node|
# |A>B| to A due to matched node's child node middle to b matched node|
# |A to B|to A due to matched node's sibling node middle to b matched node|
# |A+B|to A due to matched node's as soon as back sibling node to b matched node|
#
# CSS selector specification format description website
#
# https://wickedmagic.tistory.com/563
#
# https://junistory.blogspot.com/2017/08/css3.html
#
# ➢ Press F12 , select the corresponding part and right mouse Click Copy > Copy selector to check

# %% [markdown]
# #### Web Scrapping : Download
#
# urllib.request Various in the library Using functions (planned using functions inside the reques module within the urllib package)
#
# Data can be downloaded using HTTP or FTP , and includes a module that handles URLs
#
# 1. URL file ( png etc ) download and save
#     1) Method 1: urlretrieve () function
#     2) Method 2: urlopen () function :
# 2. IP address of your PC and client Output connection information
#
# >url = http://api.aoikujira.com/ip/ini
# >urlopen ( url ).read().decode("utf-8“)
# >urllib.parse Using
#
# Using a new url with parameters added to the URL Download
#
# 3. HTML scraping
#     (1) BeautifulSoup Various in the library Using function : No URL download function
#         Analyzing HTTP and XML ( extracting the desired part )
#     (2) lxml Use
#
# 4. RSS scraping
# 5. Specify Parser : HTML case BeautifulSoup (html target , ' html.parser ' )
#     Extract : html.body . tag ( node ) name
#     output : print ( extract part.string )
# 6. Content extraction using
#     (1) Using the find() function Example ) find( id=“title” ) Specify only one id
#     (2) Using the find_all () function . In case of multiple contents
#     Example ) find_all (“ a ”)[0][' href '] Linked url address pick up
# 7. Extract content after URL download : urlopen () + BeautifulSoup
#
# 8. Extract content using `BeautifulSoup.select_one()` : Extract one element
#     Example ) select_one (" div #meigen > h1") ( Note ) #id attribute value , .class attribute value `BeautifulSoup.select()`: Extract multiple elements into a list with a CSS selector
#     Ex ) Method 1: find(" ul ", {" class":"items "})
#          Method 2: select(" div #meigen > ul.items > li")
# 9. Download https://en.wikisource.org/wiki/%EC%A0%80%EC%9E%90:%EC%9C%A4%EB%8F%99%EC%A3%BC
#     List of works : select(”#mw-content-text > div > ul > li a”) ( reference ) #id attribute value .class attribute value
#
# 10. regular expression conjugation
# Organize
# > li = soup.find_all(href= re.compile ( r"^ https://"))
# > for e in li: print(e.attrs['href'])
#
# urljoin in urllib.parse specific using a function based on the principle url path conversion
#
# 11. Convert URL path ( Convert relative path to absolute path )
# base="http://example.com/html/a.html"
# print( urljoin(base, "b.html") ) http://example.com/html/b.html
# print( urljoin(base, " ../ index.html") ) http://example.com / index.html
# print( urljoin (base, " http: //otherExample.com/wiki") ) http: //otherExample.com/wiki print( urljoin (base, " // anotherExample.org/test") ) http: // anotherExample.org/test
#
# 12. Process HTML recursively ( Download contents of relative path linked to base URL )
# https://docs.python.org/3.5/library/

# %% [markdown]
# #### Exercise
#
# Download and save URL files
#
# **1. Download and save**

# %%
import urllib.request

# %%
url = "http://uta.pw/shodou/img/28/214.png"
savename = '../../Data/test.png'

urllib.request.urlretrieve(url, savename) # download and save
# Out:
# ('../../Data/test.png', <http.client.HTTPMessage at 0x109ca7d60>)

# %% [markdown]
# another way

# %%
mem = urllib.request.urlopen(url).read() 
with open(savename, mode = "wb") as f:
    f.write(mem)

# %% [markdown]
# **2. Accessing your PC 's IP verification API and outputting the result**

# %%
import urllib.request
url = "http://api.aoikujira.com/ip/ini"
result = urllib.request.urlopen(url)
data = result.read()

# %%
# convert binary to string
text = data.decode('utf-8')
print(text)
# Out:
# [ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=104.28.84.49
# REMOTE_HOST=104.28.84.49
# REMOTE_PORT=60816
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.10
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini

# %% [markdown]
# 바로 불러올 수도 있다

# %%
print(urllib.request.urlopen(url).read().decode('utf-8'))
# Out:
# [ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=104.28.84.49
# REMOTE_HOST=104.28.84.49
# REMOTE_PORT=55280
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.10
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini

# %% [markdown]
# **3. HTML scrapping**
#
# BeautifulSoup을 이용해 HTML문서를 떠올 수 있다

# %%
from bs4 import BeautifulSoup

#target HTML
html_example = """
<html>
    <body>
        <h1>What is Scrapping?</h1>
        <p>Analyzing web pages</p>
        <p>Extracting the desired part</p>
    </body>
</html>
"""

# %% [markdown]
# html.parser를 이용해 파싱을 쉽게 할 수 있다

# %%
soup = BeautifulSoup(html_example, 'html.parser')

# %% [markdown]
# 아래와 같은 방법으로 필요한 정보를 뽑아낼 수 있다

# %%
# Extract the desired part
h1 = soup.html.body.h1
p1 = soup.html.body.p
p2 = p1.next_sibling.next_sibling

# %%
# Print element's text 
print("h1 = " + h1.string) 
print("p = " + p1.string) 
print("p = " + p2.string)
# Out:
# h1 = What is Scrapping?
# p = Analyzing web pages
# p = Extracting the desired part

# %% [markdown]
# lxml library를 이용해서 가져오는것도 가능하다

# %%
import lxml.html as lh

tree = lh.fromstring("""
<!DOCTYPE html>
<html>
    <head>
        <title>lxml tutorials</title> 
    </head>
    <div>
        <div class="cc cv"> <i>Hello</i> World!!!</div>
    </div> 
</html>""")

# %%
# css selector
selectors = tree.cssselect('.cc')

# %%
print(len(selectors)) # 1 (iterators)
elements = selectors[0].cssselect('i')[0] # <i>Hello</i> 
print(elements.text_content()) # Hello 
print(selectors[0].text_content()) # Hello World!!! 
print(selectors[0].attrib) # {'class': 'cc cv'} 
print(selectors[0].get('class')) # 'cc cv'
# Out:
# 1
# Hello
#  Hello World!!!
# {'class': 'cc cv'}
# cc cv

# %% [markdown]
# xpath를 사용할 수도 있다

# %%
from lxml import etree
root = etree.XML("""
<root>
    <TEXT1 class="myitem">one</TEXT1> 
    <TEXT2 class="myitem">two</TEXT2> 
    <TEXT3 class="myitem">three</TEXT3> 
    <v-TEXT4 class="v-list">four</v-TEXT4>
</root>
""")

# %%
items = root.xpath("//*[re:test(local-name(), '^TEXT.*')]", 
                   namespaces = {'re' : 'http://exslt.org/regular-expressions'})

# %%
for item in items : print(item.text) ; print(item.attrib)
# Out:
# one
# {'class': 'myitem'}
# two
# {'class': 'myitem'}
# three
# {'class': 'myitem'}

# %%
items = root.xpath("//*[@class='myitem']")
for item in items : print(item.text) ; print(item.attrib)
# Out:
# one
# {'class': 'myitem'}
# two
# {'class': 'myitem'}
# three
# {'class': 'myitem'}

# %% [markdown]
# **RSS scrapping**

# %%
import feedparser
d = feedparser.parse('http://www.aladin.co.kr/rss/special_new/351')

# %%
for entry in d.entries :
    print('Title :', entry.title ) 
    print('Category :', entry.category ) 
    print('Link :', entry.link )
# Out:
# Title : 핵심만 요약한 통계와 머신러닝 파이썬 코드북/조정임 지음/알고보니(AlgoBoni)
# Category : 국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325299435
# Title : For Teacher, 디지털 교실에서 활용하는 AI와 챗봇 with 챗GPT/김규섭 외 지음/넷마루
# Category : 국내도서>컴퓨터/모바일>인공지능
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325297918
# Title : 생성 AI를 활용한 나만의 콘텐츠 만들기/김민후 지음/영진.com(영진닷컴)
# Category : 국내도서>컴퓨터/모바일>인공지능
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325180162
# Title : PPT 디자인으로 월급 벌기/김다솔 지음/길벗
# Category : 국내도서>컴퓨터/모바일>오피스(엑셀/파워포인트)>파워포인트
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325172638
# Title : 된다! 7일 실무 한글/한정희 지음/이지스퍼블리싱
# Category : 국내도서>컴퓨터/모바일>오피스(엑셀/파워포인트)>한글(한글과컴퓨터)
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325148579
# Title : 앤서블로 시작하는 인프라 자동화/장현정.이태훈.김병수 지음/한빛미디어
# Category : 국내도서>컴퓨터/모바일>컴퓨터 공학>소프트웨어 공학
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325105140
# Title : 개발자를 위한 실전 선형대수학/마이크 코헨 지음, 장정호 옮김/한빛미디어
# Category : 국내도서>컴퓨터/모바일>컴퓨터 공학>컴퓨터공학/전산학 개론
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325100604
# Title : 2024 이기적 컴퓨터활용능력 2급 실기 기본서/박윤정 지음/영진.com(영진닷컴)
# Category : 국내도서>컴퓨터/모바일>활용능력>컴퓨터활용능력>컴퓨터활용능력 실기
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325094775
# Title : 마인크래프트 레전드 가이드/Mojang AB 지음, 이주안 옮김/영진.com(영진닷컴)
# Category : 국내도서>컴퓨터/모바일>PC/게임/디지털 카메라>게임
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325057973
# Title : 객체지향 파이썬/어브 캘브 지음, 박찬성 옮김/제이펍
# Category : 국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325055345
# Title : 회사에서 엑셀로 살아남기/김경자 지음/한빛미디어
# Category : 국내도서>컴퓨터/모바일>오피스(엑셀/파워포인트)>엑셀
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325029840
# Title : 된다! 책 만들기 with 인디자인/김혜린 지음/이지스퍼블리싱
# Category : 국내도서>컴퓨터/모바일>그래픽/멀티미디어>그래픽 일반
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325027474
# Title : 혁신 왕국의 DNA/이순영 지음/지식과감성#
# Category : 국내도서>컴퓨터/모바일>컴퓨터 공학>컴퓨터공학/전산학 개론
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325026180
# Title : 인공지능 활용교육/이동국 외 지음/테크빌교육
# Category : 국내도서>사회과학>교육학>교육 일반
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325025710
# Title : AutoML 인 액션/칭취안 송.하이펑 진.시아 후 지음, 박찬성 옮김/한빛미디어
# Category : 국내도서>컴퓨터/모바일>인공지능
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=325025568
# Title : 줄리아 머신러닝, 딥러닝, 강화학습/김태훈 지음/제이펍
# Category : 국내도서>컴퓨터/모바일>인공지능
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324968536
# Title : 문제 해결을 위한 알고리즘 with 수학/요네다 마사타카 지음, 윤인성 옮김/위키북스
# Category : 국내도서>컴퓨터/모바일>컴퓨터 공학>자료구조/알고리즘
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324967287
# Title : 당신의 소프트웨어 프로젝트가 망하는 이유/박창욱 지음/와이출판
# Category : 국내도서>컴퓨터/모바일>컴퓨터 공학>소프트웨어 공학
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324962892
# Title : 일러스트레이터와 웹툰 작가를 위한 : 클립 스튜디오 입문 교실/사이도런치 지음, 고영자 옮김/영진.com(영진닷컴)
# Category : 국내도서>컴퓨터/모바일>웹디자인/홈페이지>일러스트레이터
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324926369
# Title : 자율주행을 위한 비주얼 슬램/가오시앙.장타오 지음, 김필은 옮김/지니북스
# Category : 국내도서>대학교재/전문서적>공학계열>컴퓨터공학>컴퓨터공학/전산학 개론
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324925730
# Title : 요즘 우아한 개발/우아한형제들 지음/골든래빗(주)
# Category : 국내도서>컴퓨터/모바일>프로그래밍 개발/방법론>프로그래밍 기초/개발 방법론
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324920954
# Title : GPT-4, ChatGPT, 라마인덱스, 랭체인을 활용한 인공지능 프로그래밍/후루카와 히데카즈 지음, 트랜스메이트 옮김/위키북스
# Category : 국내도서>컴퓨터/모바일>인공지능
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324901870
# Title : 2024 시나공 컴퓨터활용능력 2급 필기 기본서/길벗 R&D 외 지음/길벗
# Category : 국내도서>컴퓨터/모바일>활용능력>컴퓨터활용능력>컴퓨터활용능력 필기
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324764106
# Title : 게임 콘셉트 디자인/남기덕 지음/길벗캠퍼스
# Category : 국내도서>대학교재/전문서적>공학계열>컴퓨터공학>그래픽/멀티미디어
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324754977
# Title : 최강의 AI 공쌤반 아이들/공민수 지음/리틀에이
# Category : 국내도서>어린이>과학/수학/컴퓨터>컴퓨터와 코딩
# Link : http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=324752412

# %% [markdown]
# **4. HTML parsing**

# %%
from bs4 import BeautifulSoup

html_example = """
<html>
    <body>
        <h1 id="title">What is Scrapping?</h1>
        <p id="body">Analyzing web pages</p>
        <p>Extracting the desired part</p>
    </body>
</html>
"""

# %%
soup = BeautifulSoup(html_example, 'html.parser')

# Extract the desired part with the find() method
title = soup.find(id = "title")
body = soup.find(id = "body")

# %%
# print the text part 
print("#title = " + title.string ) 
print("#body = " + body.string )
# Out:
# #title = What is Scrapping?
# #body = Analyzing web pages

# %%
html_example = """
<html>
    <body>
        <ul> 
            <li> 
                <a href ="http://www.naver.com">naver</a>
            </li> 
            <li> 
                <a href ="http://www.daum.net">daum</a>
            </li> 
        </ul> 
    </body>
</html>
"""

# %%
soup = BeautifulSoup(html_example, 'html.parser')

links = soup.find_all("a") # a tag가 있는 것은 모두 찾는다
links
# Out:
# [<a href="http://www.naver.com">naver</a>,
#  <a href="http://www.daum.net">daum</a>]

# %%
linksA = soup.findAll("a") # same as find_all
links[0].text
# Out:
# 'naver'

# %%
links[0].string # text attribute와 같다
# Out:
# 'naver'

# %%
for a in links :
    href = a.attrs['href']
    text = a.format_string
    print(text, '>', href)
# Out:
# <bound method PageElement.format_string of <a href="http://www.naver.com">naver</a>> > http://www.naver.com
# <bound method PageElement.format_string of <a href="http://www.daum.net">daum</a>> > http://www.daum.net

# %% [markdown]
# **5. HTML/XML from webpage**

# %%
from bs4 import BeautifulSoup
import urllib.request as req
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

# Get data with urlopen()
result = req.urlopen(url)

# %%
soup = BeautifulSoup(result, 'html.parser')

# Extract the desired data
title = soup.find ("title").string # node name title 
wf = soup.find("wf").string # nodename wf 
print(title)
print(wf)
# Out:
# 기상청 육상 중기예보
# ○ (하늘상태 및 강수) 전국이 대체로 맑거나 가끔 구름많겠고, 10월 1일(일) 오후 강원영동에는 비가 오는 곳이 있겠습니다.<br />○ (기온) 아침 기온은 8~18도, 낮 기온은 19~26도로 평년(최저기온 10~18도, 최고기온 22~25도)과 비슷하거나 조금 낮겠습니다. <br />○ (해상) 10월 1일(일)부터 2일(월)까지 서해남부해상과 남해서부해상, 제주도해상에서 물결이 1.0~3.0m로 높게 일겠습니다.<br />○ (주말전망) 전국이 대체로 맑겠으나, 9월 30일(토) 수도권과 강원영서는 아침부터 낮 사이 가끔 구름많겠고, 제주도는 흐리겠습니다. <br />              10월 1일(일) 강원영동은 구름많고 오후에 비가 오는 곳이 있겠습니다. 아침 기온은 12~20도, 낮 기온은 22~26도가 되겠습니다.
# /Users/junghunlee/anaconda3/envs/Webscraping/lib/python3.10/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %% [markdown]
# **6. CSS selectors or Extract details using tag (id, class, etc. )**

# %%
html_example1 = """
<html>
    <body>
        <div id=" meigen ">
            <h1> Wikibooks books </h1>
            <ul class="items">
                <li> Introduction to Unity Game Effects </li>
                <li> iPhone app development textbook starting with Swift </li> <li> The classics of modern website design </li>
            </ul> 
        </div>
    </body>
</html>"""

html_example2 = """
<html>
    <body>
        <ul class="list_nav type_fix">
            <li class="nav_item">
                <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
            </li>
            <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
            <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li> 
            <li class="nav_item"><a href="https://kin.naver.com/" class="nav" data-clk="svc.kin">지식iN</a></li>
            <li class="nav_item"><a href="https://shopping.naver.com/" class="nav shop" data-clk="svc.shopping"><span class="blind">쇼핑</span></a></li>
            <li class="nav_item"><a href="https://shoppinglive.naver.com/home" class="nav shoplive" data- clk="svc.shoppinglive"><span class="blind">쇼핑LIVE</span></a></li>
            <li class="nav_item"><a href="https://order.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li> 
            <li class=" nav_item "><a href ="https://tv.naver.com/" class=" nav " data- clk =" svc.tvcast "> < i class=" ico_tv "></ i >TV</a>
            </li>
        </ul>
    </body>
</html>"""

# %%
# parse HTML
soup = BeautifulSoup(html_example2, 'html.parser')

# %%
# Extract the necessary parts with a CSS query
# Extract the title part
h1 = soup.select_one("div#meigen > h1").string 
print("h1 = ", h1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 3
#       1 # Extract the necessary parts with a CSS query
#       2 # Extract the title part
# ----> 3 h1 = soup.select_one("div#meigen > h1").string
#       4 print("h1 = ", h1)
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %%
soup = BeautifulSoup(html_example1, 'html.parser')
# extract the list part
# Method 1: Go through
list1 = soup.find("ul", {"class" : "items"}) # compare with li_list
list1.find("li").string
list2 = list1.find_all("li") # Since string cannot be used directly in list , use for statement 
for one in list2: print("li =", one. string)
# Out:
# li =  Introduction to Unity Game Effects
# li =  iPhone app development textbook starting with Swift
# li =  The classics of modern website design

# %%
# method 2 : Go to the target directly
li_list = soup.select('div#meigen>ul.items>li')
li_list = soup.select ("ul.items>li") # Same result as above
for li in li_list : print('li =', li.string)

# %%
soup = BeautifulSoup(html_example2, 'html.parser')
ul = soup.find("ul", {"class":"list_nav type_fix"}) 
lis = ul.find_all("li")
dataf = [] 
for li in lis:
    tag = li.find("a")
    link = tag.attrs['href'] 
text = tag.text 
print(text, link)
# Out:
#  < i class=" ico_tv ">TV https://tv.naver.com/

# %% [markdown]
# **7. CSS from webpage**

# %%
url = "https://en.wikipedia.org/wiki/South_Korea"
res = req.urlopen(url)
soup = BeautifulSoup(res, 'html.parser')
# just below the mw-content-text
# ul _ just below the tag
# under the li tag
# Select all a tags

# %%
a_list = soup.select('#mw-content-text > div > ul > li a')
for a in a_list :
    name = a.string
    print('-', name)

# %% [markdown]
# **8.CSS from HTML file**

# %%
file_point = open('../../Data/books.html', encoding = 'utf-8')
soup = BeautifulSoup(file_point, 'html.parser')

# %%
sel = lambda q : print(soup.select_one(q).string) 
sel("#nu")
sel("li#nu")
sel("ul > li#nu")
sel("#bible #nu")
sel("#bible > #nu")
sel("ul#bible > li#nu")
sel("li[id='nu']")
sel("li:nth-of-type(4)")
# Out:
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers
# Numbers

# %%
# 그 밖의 방법
print(soup.select("li")[3].string) 
print(soup.find_all("li")[3].string)
# Out:
# Numbers
# Numbers

# %%
file_point = open('../../Data/fruits-vegetables.html', encoding = 'utf-8')
soup = BeautifulSoup(file_point, 'html.parser')

# %%
# CSS 선택자로 추출하기
#print(soup.select_one("li:nth-of-type(6)").string) # 작동 안됨
print(soup.select_one("#ve-list > li:nth-of-type(4)").string) 
print(soup.select("#ve-list > li[data-lo='us']")[1].string)
print(soup.select ("#ve-list > li.black")[1].string)
# Out:
# 아보카도
# 아보카도
# 아보카도

# %%
# extract with find method
cond = {'data-lo' : 'us', 'class' : 'black'}
print(soup.find('li', cond).string)
# Out:
# 아보카도

# %%
# use the find method consecutively
print(soup.find(id = 've-list').find('li', cond).string)
# Out:
# 아보카도

# %% [markdown]
# **9. Using regular expressions**

# %%
html = '''
<ul>
    <li> <a href ="hoge.html"> hoge </li>
    <li> <a href ="https://example.com/ fuga "> fuga *</li> 
    <li> <a href ="https://example.com/foo"> foo*</li> 
    <li> <a href ="http://example.com/ aaa "> aaa </li> 
</ul>'''

soup = BeautifulSoup(html, 'html.parser')

# %%
import re
# Extract
li = soup.find_all( href = re.compile (r"^https ://")) 
for e in li: print(e.attrs[' href '])

# %% [markdown]
# **10. URL designation method**

# %%
from urllib.parse import urljoin

base = "http://example.com/html/a.html" 
print(urljoin(base, "b.html"))
print(urljoin(base, "sub/c.html"))
print(urljoin(base, "../index.html")) 
print(urljoin(base, "../img/hoge.png")) 
print(urljoin(base, "../css/hoge.css"))
print(urljoin(base, "/hoge.html"))
print(urljoin(base, "http://otherExample.com/wiki")) 
print(urljoin(base, "//anotherExample.org/test"))
# Out:
# http://example.com/html/b.html
# http://example.com/html/sub/c.html
# http://example.com/index.html
# http://example.com/img/hoge.png
# http://example.com/css/hoge.css
# http://example.com/hoge.html
# http://otherExample.com/wiki
# http://anotherExample.org/test

# %% [markdown]
# `urljoin()`함수를 사용해서 url 뒤에 주소를 붙일 수 있다

# %% [markdown]
# **11. XML analyze**

# %%
import os.path

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108" 
savename = "../../Data/forecast.xml" 
if not os.path.exists(savename): req.urlretrieve(url ,savename) # create XML data

# %%
xml = open(savename, "r", encoding = "utf-8").read() 
soup = BeautifulSoup(xml, 'html.parser')

# %%
info = {} # check each region
for location in soup.find_all("location"): 
    name = location.find('city').string 
    weather = location.find('wf').string
if not (weather in info): 
    info[weather] = [] 
    info[weather].append(name)

# %%
# Output the weather for each region separately 
for weather in info.keys(): print("+", weather)
for name in info[weather]: print("| -", name)
# Out:
# + 구름많음
# | - 서귀포

# %% [markdown]
# #### Web analytics application
#
# **1. How to read the URL**

# %%
import requests

url = 'https://www.naver.com/'
req = requests.get(url)
html = req.text
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ❖ URL Parameters : Insert parameters into the URL to allow
#
# URL parameters are separated by an equal sign (=) and the first parameter is always followed by a question mark(I'll try {URL parameter } by Googling)
#
# ❖ Example
#
# Using Meteorological Agency RSS(XML data download)
#
# The parameter ( stnId ) specifies
#
# Korea Meteorological Administration RSS address : http://www.kma.go.kr/weather/forecast/mid-term-
# rss3.jsp
#
# New address with parameters added : url = http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp ?stnId=108
#
# [Meteorological Administration area code data]

# %% [markdown]
# **2. URL + parameters**

# %%
import urllib.request
import urllib.parse
url0 = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

values = {
    'stnld' : '109'
}
params = urllib.parse.urlencode(values)

# %%
# Create request-only URL 
url = url0 + "?" + params 
print("url =", url)
# Out:
# url = http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=109

# %%
# download
data = urllib.request.urlopen(url).read() 
text = data.decode("utf-8")
print(text[:100])
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>

# %% [markdown]
# **3. Search stocks on Google**
#
# ############## Search stocks on Google ( eg : tesla stock) and extract the stock price ( two urls have the same result : use the shorter one )
#
# https://www.google.com/ search?q = tesla+stock&ei =Q9_eYILWCMS4mAX0_p3QBA&o...
#
# https://www.google.com/search?q=tesla+stock

# %%
url = "https://www.google.com/search?q=" 
company = "tesla"
req = requests.get(url + company + "+stock") 
html = req.text
soup = BeautifulSoup(html, "html.parser")
# tags = soup.select("span.IsqQVc.NprOob.XcVN5d.wT3VGc") 
# class = news.tit 
# print(price[0].text)

# %%
tags = soup.select("div.BNeawe.iBp4i.AP7Wnd")
print(tags)
# Out:
# [<div class="BNeawe iBp4i AP7Wnd"><div><div class="BNeawe iBp4i AP7Wnd">244.12 <span class="rQMQod AWuZUe">+0.00 (0.00%)</span></div></div></div>, <div class="BNeawe iBp4i AP7Wnd">244.12 <span class="rQMQod AWuZUe">+0.00 (0.00%)</span></div>]

# %%
for tag in tags: print(tag.text)
# Out:
# 244.12 +0.00 (0.00%)
# 244.12 +0.00 (0.00%)

# %%
tags[0].text.split(' ')[0]
# Out:
# '244.12'

# %% [markdown]
# **4. Naver keyword-based news search**

# %%
url = "https://search.naver.com/search.naver?where=news&sm=tab_jum&query=?" 
keyword = "artificial intelligence"
req = requests.get( url + keyword)
html = req.text
soup = BeautifulSoup(html, "html.parser")

# %%
############# news title and url extraction 
titles = soup.select(".news_tit") # class = news.tit 
print(titles[0])
print(titles[0].text)
print(titles[0]["href"])
print(titles[0]["title"])
title_list = []
url_list = []
for title in titles:
    title_list.append(title.text) 
    url_list.append(title["href"])
# Out:
# <a class="news_tit" href="https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145" onclick="return goOtherCR(this, 'a=nws*e.tit&amp;r=1&amp;i=88166597_000000000000000000043869&amp;g=640.0000043869&amp;u='+urlencode(this.href));" target="_blank" title="Artificial intelligence everywhere"><mark>Artificial intelligence</mark> everywhere</a>
# Artificial intelligence everywhere
# https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145
# Artificial intelligence everywhere

# %%
print(title_list)
# Out:
# ['Artificial intelligence everywhere', 'Getty Images Artificial Intelligence', '경남교육청, 교육데이터 기반 인공지능 모델·알고리즘 개발 발표', 'UN General Assembly Artificial Intelligence', '임태희 교육감, 슐라이허 OECD 교육·기술국장과 미래교육 협력 논의', '의왕시, 카이스트 김대식 교수 초청 제6회 의왕아카데미 개최', 'The Man Who Trapped Us in Databases', '금융안정에 대한 AI의 잠재적 위협과 관리 방안의 모색', 'Huawei Connect 2023: Accelerating intelligence for shared success', "AI(artificial intelligence)&CI(collective intelligence) 이용 '번역공장 엔..."]

# %%
len(title_list)
# Out:
# 10

# %%
print(url_list)
# Out:
# ['https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145', 'https://n.news.naver.com/mnews/article/077/0006039745?sid=104', 'http://www.breaknews.com/989818', 'https://n.news.naver.com/mnews/article/077/0006039553?sid=104', 'http://www.breaknews.com/989801', 'http://www.breaknews.com/989757', 'https://www.nytimes.com/2023/09/22/magazine/hank-asher-data.html?partner=naver', 'http://www.ifs.or.kr/bbs/board.php?bo_table=News&wr_id=53628', 'https://www.businesskorea.co.kr/news/articleView.html?idxno=202379', 'http://www.fntoday.co.kr/news/articleView.html?idxno=302012']

# %%
len(url_list)
# Out:
# 10

# %% [markdown]
# list comprehension으로도 추가할 수 있다

# %%
title_list = [title["title"] for title in titles] 
print(title_list)
# Out:
# ['Artificial intelligence everywhere', 'Getty Images Artificial Intelligence', '경남교육청, 교육데이터 기반 인공지능 모델·알고리즘 개발 발표', 'UN General Assembly Artificial Intelligence', '임태희 교육감, 슐라이허 OECD 교육·기술국장과 미래교육 협력 논의', '의왕시, 카이스트 김대식 교수 초청 제6회 의왕아카데미 개최', 'The Man Who Trapped Us in Databases', '금융안정에 대한 AI의 잠재적 위협과 관리 방안의 모색', 'Huawei Connect 2023: Accelerating intelligence for shared success', "AI(artificial intelligence)&CI(collective intelligence) 이용 '번역공장 엔진 1.5 시스템' 구축"]

# %%
url_list = [title["href"] for title in titles] 
print(url_list)
# Out:
# ['https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145', 'https://n.news.naver.com/mnews/article/077/0006039745?sid=104', 'http://www.breaknews.com/989818', 'https://n.news.naver.com/mnews/article/077/0006039553?sid=104', 'http://www.breaknews.com/989801', 'http://www.breaknews.com/989757', 'https://www.nytimes.com/2023/09/22/magazine/hank-asher-data.html?partner=naver', 'http://www.ifs.or.kr/bbs/board.php?bo_table=News&wr_id=53628', 'https://www.businesskorea.co.kr/news/articleView.html?idxno=202379', 'http://www.fntoday.co.kr/news/articleView.html?idxno=302012']

# %%
contents = soup.select(".api_txt_lines") # class = api_txt_lines 
print(contents[0])
print(contents[0].text)
# Out:
# <a class="api_txt_lines dsc_txt_wrap" href="https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145" onclick="return goOtherCR(this, 'a=nws*e.body&amp;r=1&amp;i=88166597_000000000000000000043869&amp;g=640.0000043869&amp;u='+urlencode(this.href));" target="_blank">There is an <mark>artificial intelligence</mark> (AI)-enabled voice speaker that once used to be a fad. After early amusement, it is now hardly used. There is a robot vacuum cleaner that I recently purchased. I have to question its <mark>intelligence</mark> as it often stops after hitting a hurdle...</a>
# There is an artificial intelligence (AI)-enabled voice speaker that once used to be a fad. After early amusement, it is now hardly used. There is a robot vacuum cleaner that I recently purchased. I have to question its intelligence as it often stops after hitting a hurdle...

# %%
content_list = [content.text for content in contents] 
print(content_list)
# Out:
# ['There is an artificial intelligence (AI)-enabled voice speaker that once used to be a fad. After early amusement, it is now hardly used. There is a robot vacuum cleaner that I recently purchased. I have to question its intelligence as it often stops after hitting a hurdle...', "This photo provided by Getty Images shows an example of the company's artificial intelligence image-generator. The Seattle-based photo stock company is taking a two-pronged approach to the threat and opportunity that AI poses to its business. On Monday, Sept. 25, 2023 it...", 'It is assumed that there may be errors in the English translation.> Gyeongnam Office of Education announces development of artificial intelligence model and algorithm based on education data AI teaching and learning platform, utilized in customized learning and life guidance areas The Gyeongsangnam-do...', 'Rose Nakasi, a Ugandan computer scientist, checks her computer during an interview, Friday, Sept. 22, 2023, in New York. Nakasi is working on using AI to ease microscopic analysis of blood samples to diagnose such diseases as malaria in countries that are short on...', 'It is assumed that there may be errors in the English translation.> Superintendent Lim Tae-hee discusses future education cooperation with OECD Education and Technology Director Schleicher “We hope to actively cooperate with the OECD in training and evaluation on the use of artificial intelligence.”...', "In this day's lecture, Professor Kim explained the current level of artificial intelligence, which has developed dramatically due to deep learning, and vividly conveyed to citizens examples of the use of generative AI such as Chat GPT and how to prepare for the future brought by AI. . Professor Dae-sik Kim...", 'They allow computers inside police departments, intelligence agencies, hospitals, banks, insurance companies, political parties and marketing firms to understand personal behavior and, increasingly, as artificial intelligence and machine learning expand into every corner of...', '인공지능(Artificial Intelligence; 이하 AI) 열풍은 AI가 가져올 무한한 가능성에 대해 부푼 기대를 자아내고 있다. 금융도 AI의 활용이 빠르게 늘어나고 있는 분야이다. 특히 심층학습(deep learning) 기법을 통해 AI의 예측력이 획기적으로 고도화되면서 AI가 효율성 제고, 금융포용 확대, 소비자 만족도 개선...', "As artificial intelligence gains steam, and its impact on industry continues to grow, Huawei's All Intelligence strategy is designed to help all industries make the most of new strategic opportunities presented by AI. Key to this strategy is providing the massive amounts of...", "IT 기업 ㈜크리포터가 급속도로 성장하는 AI 번역 시장에 발맞추어 번역공장 엔진 1.5 시스템을 서비스인 '번역공장'에 탑재했다고 밝혔다. '번역공장'은 공장도 가격의 번역 서비스를 유튜브, 웹툰, 영화, 드라마 등 K-컨텐츠에 제공하는 다국어 자막 및 전문 번역 서비스다. ChatGPT 등장 이후 AI 번역에 대한..."]

# %% [markdown]
# #### Web analytics application
#
# **1. How to read the URL**
#
# request, urllib.request를 사용하는 방법이 존재한다

# %%
import requests
from bs4 import BeautifulSoup
url = "https://www.naver.com/"
req = requests.get(url)
html = req.text
soup = BeautifulSoup(html, 'html.parser')

# %%
import urllib.request

url = 'https://www.naver.com/'
req = urllib.request.Request(url)
html = urllib.request.urlopen(req)
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# 어느 쪽을 사용하더라도 결과는 같다

# %% [markdown]
# **Web scrapping : download**
#
# ❖ URL Parameters : Insert parameters into the URL to allow
#
# URL parameters are separated by an equal sign (=) and the first parameter is always followed by a question mark(I'll try {URL parameter } by Googling)
#
# ❖ Example
#
# Using Meteorological Agency RSS (XML data download )
#
# The parameter ( stnId ) specifies
#
# - Korea Meteorological Administration RSS address : http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp
# - New address with parameters added : url = http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp ?stnId=108

# %% [markdown]
# **2. URL + parameters**

# %%
import urllib.parse
url0 = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

# URL encode
values = {
    'stnld' : '109'
}
params = urllib.parse.urlencode(values)

# Create request-only URL
url = url0 + "?" + params
print(f"url = {url}")
# Out:
# url = http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnld=109

# %% [markdown]
# download data

# %%
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")
#print(text)

# %% [markdown]
# **3. Search stocks on Google**
#
# https://www.google.com/search?q=tesla+stock&ei=Q9_eYILWCMS4mAX0_p3QBA&o...
#
# https://www.google.com/search?q=tesla+stock

# %%
url = "https://www.google.com/search?q="
company = "tesla"
req = requests.get(url + company + "+stock")
html = req.text
soup = BeautifulSoup(html, "html.parser")

# %%
tags = soup.select("div.BNeawe.iBp4i.AP7Wnd")

# %% [markdown]
# tags 내에는 주가에 대한 정보가 저장되어 있다

# %%
print(tags)
# Out:
# [<div class="BNeawe iBp4i AP7Wnd"><div><div class="BNeawe iBp4i AP7Wnd">250.22 <span class="rQMQod AWuZUe">+3.84 (1.56%)</span></div></div></div>, <div class="BNeawe iBp4i AP7Wnd">250.22 <span class="rQMQod AWuZUe">+3.84 (1.56%)</span></div>]

# %%
for tag in tags : print(tag.text)
# Out:
# 250.22 +3.84 (1.56%)
# 250.22 +3.84 (1.56%)

# %% [markdown]
# 주가의 가격은 아래와 같이 parsing 가능하다

# %%
tags[0].text.split(' ')[0]
# Out:
# '250.22'

# %% [markdown]
# **4. Naver keyword-based news search**
#
# Search artificial intelligence(news) on Naver
#
# https://search.naver.com/search.naver?where=news&sm=tab_jum&query=artificial%20intelligence

# %%
url = "https://search.naver.com/search.naver?where=news&sm=tab_jum&query=?"
keyword = "artificial intelligence"
req = requests.get(url + keyword)
html = req.text
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# news title and url extraction

# %%
titles = soup.select(".news_tit") # class = news.tit
print(titles[0])
# Out:
# <a class="news_tit" href="https://n.news.naver.com/mnews/article/077/0006042149?sid=104" onclick="return goOtherCR(this, 'a=nws*e.tit&amp;r=1&amp;i=880000DD_000000000000000006042149&amp;g=&amp;u='+urlencode(this.href));" target="_blank" title="NSA Artificial Intelligence">NSA <mark>Artificial Intelligence</mark></a>

# %%
print(titles[0].text)
# Out:
# NSA Artificial Intelligence

# %%
print(titles[0]['href']) # href tag
# Out:
# https://n.news.naver.com/mnews/article/077/0006042149?sid=104

# %%
print(titles[0]['title'])
# Out:
# NSA Artificial Intelligence

# %%
title_list = []
url_list = []
for title in titles :
    title_list.append(title.text)
    url_list.append(title['href'])

# %%
print(title_list)
# Out:
# ['NSA Artificial Intelligence', 'Artificial intelligence everywhere', 'Monday Briefing', 'Getty Images Artificial Intelligence', '금융안정에 대한 AI의 잠재적 위협과 관리 방안의 모색', '경남교육청, 교육데이터 기반 인공지능 모델·알고리즘 개발 발표', 'The Man Who Trapped Us in Databases', 'To Bring Socializing Back to Social Networks, Apps Try A.I. Imagery', 'UN General Assembly Artificial Intelligence', 'European Central Bank Is Experimenting With a New Tool: A.I.']

# %%
print(url_list)
# Out:
# ['https://n.news.naver.com/mnews/article/077/0006042149?sid=104', 'https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145', 'https://www.nytimes.com/2023/09/25/briefing/ukraine-hollywood-strike-deal.html?partner=naver', 'https://n.news.naver.com/mnews/article/077/0006039745?sid=104', 'http://www.ifs.or.kr/bbs/board.php?bo_table=News&wr_id=53628', 'http://www.breaknews.com/989818', 'https://www.nytimes.com/2023/09/22/magazine/hank-asher-data.html?partner=naver', 'https://www.nytimes.com/2023/09/27/technology/ai-images-social-media-sharing.html?partner=naver', 'https://n.news.naver.com/mnews/article/077/0006039551?sid=104', 'https://www.nytimes.com/2023/09/28/business/european-central-bank-artificial-intelligence.html?partner=naver']

# %% [markdown]
# 또는 아래의 방법을 사용할 수 있다 (list comprehension)

# %%
title_list = [title['title'] for title in titles]
print(title_list)
# Out:
# ['NSA Artificial Intelligence', 'Artificial intelligence everywhere', 'Monday Briefing', 'Getty Images Artificial Intelligence', '금융안정에 대한 AI의 잠재적 위협과 관리 방안의 모색', '경남교육청, 교육데이터 기반 인공지능 모델·알고리즘 개발 발표', 'The Man Who Trapped Us in Databases', 'To Bring Socializing Back to Social Networks, Apps Try A.I. Imagery', 'UN General Assembly Artificial Intelligence', 'European Central Bank Is Experimenting With a New Tool: A.I.']

# %%
url_list = [title['href'] for title in titles]
print(url_list)
# Out:
# ['https://n.news.naver.com/mnews/article/077/0006042149?sid=104', 'https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145', 'https://www.nytimes.com/2023/09/25/briefing/ukraine-hollywood-strike-deal.html?partner=naver', 'https://n.news.naver.com/mnews/article/077/0006039745?sid=104', 'http://www.ifs.or.kr/bbs/board.php?bo_table=News&wr_id=53628', 'http://www.breaknews.com/989818', 'https://www.nytimes.com/2023/09/22/magazine/hank-asher-data.html?partner=naver', 'https://www.nytimes.com/2023/09/27/technology/ai-images-social-media-sharing.html?partner=naver', 'https://n.news.naver.com/mnews/article/077/0006039551?sid=104', 'https://www.nytimes.com/2023/09/28/business/european-central-bank-artificial-intelligence.html?partner=naver']

# %% [markdown]
# news context extraction을 위해서 다음과 같은 방법을 고안할 수 있다

# %%
contents = soup.select(".api_txt_lines") # class = api_txt_lines
#print(contents[0])
print(contents[0].text)
# Out:
# The National Security Agency is starting an artificial intelligence security center — a crucial mission as AI capabilities are increasingly acquired, developed and integrated into U.S. defense and intelligence systems. The agency's outgoing director, Army Gen. Paul...

# %%
content_list = [content.text for content in contents]
print(content_list)
# Out:
# ["The National Security Agency is starting an artificial intelligence security center — a crucial mission as AI capabilities are increasingly acquired, developed and integrated into U.S. defense and intelligence systems. The agency's outgoing director, Army Gen. Paul...", 'There is an artificial intelligence (AI)-enabled voice speaker that once used to be a fad. After early amusement, it is now hardly used. There is a robot vacuum cleaner that I recently purchased. I have to question its intelligence as it often stops after hitting a hurdle...', 'In the coming days, guild members will vote on whether to accept the deal, which includes most of what they had demanded from studios, including increases in royalty payments for streaming content and guarantees that artificial intelligence will not encroach on writers’...', "This photo provided by Getty Images shows an example of the company's artificial intelligence image-generator. The Seattle-based photo stock company is taking a two-pronged approach to the threat and opportunity that AI poses to its business. On Monday, Sept. 25, 2023 it...", '인공지능(Artificial Intelligence; 이하 AI) 열풍은 AI가 가져올 무한한 가능성에 대해 부푼 기대를 자아내고 있다. 금융도 AI의 활용이 빠르게 늘어나고 있는 분야이다. 특히 심층학습(deep learning) 기법을 통해 AI의 예측력이 획기적으로 고도화되면서 AI가 효율성 제고, 금융포용 확대, 소비자 만족도 개선...', 'It is assumed that there may be errors in the English translation.> Gyeongnam Office of Education announces development of artificial intelligence model and algorithm based on education data AI teaching and learning platform, utilized in customized learning and life guidance areas The Gyeongsangnam-do...', 'They allow computers inside police departments, intelligence agencies, hospitals, banks, insurance companies, political parties and marketing firms to understand personal behavior and, increasingly, as artificial intelligence and machine learning expand into every corner of...', 'Instagram, Facebook, Snapchat and several newcomers are betting on artificial intelligence to rejuvenate the fun, interactivity and whimsy of creating and sharing images. Myuri Thiruna, a freelance photographer in Toronto, used to post frequently on Instagram and discuss...', 'Amandeep Singh Gill, the United Nations tech policy chief, speaks during an interview with The Associated Press, Friday, Sept. 22, 2023, at U.N. headquarters. (AP Photo/Mary Altaffer)', 'Artificial intelligence may help policymakers understand inflation and regulate big lenders, the central bank said. The European Central Bank said on Thursday that it was exploring ways to use artificial intelligence to better understand inflation and support its oversight...']

# %% [markdown]
# news information building (combine title, url, content)

# %%
news_list = zip(title_list, url_list, content_list)
news_info_list = []
for news in news_list :
    news_dict = {
        'title' : news[0],
        'url' : news[1],
        'content' : news[2]
    }
    news_info_list.append(news_dict)
news_info_list
# Out:
# [{'title': 'NSA Artificial Intelligence',
#   'url': 'https://n.news.naver.com/mnews/article/077/0006042149?sid=104',
#   'content': "The National Security Agency is starting an artificial intelligence security center — a crucial mission as AI capabilities are increasingly acquired, developed and integrated into U.S. defense and intelligence systems. The agency's outgoing director, Army Gen. Paul..."},
#  {'title': 'Artificial intelligence everywhere',
#   'url': 'https://koreajoongangdaily.joins.com/news/2023-09-26/opinion/columns/Artificial-intelligence-everywhere/1879145',
#   'content': 'There is an artificial intelligence (AI)-enabled voice speaker that once used to be a fad. After early amusement, it is now hardly used. There is a robot vacuum cleaner that I recently purchased. I have to question its intelligence as it often stops after hitting a hurdle...'},
#  {'title': 'Monday Briefing',
#   'url': 'https://www.nytimes.com/2023/09/25/briefing/ukraine-hollywood-strike-deal.html?partner=naver',
#   'content': 'In the coming days, guild members will vote on whether to accept the deal, which includes most of what they had demanded from studios, including increases in royalty payments for streaming content and guarantees that artificial intelligence will not encroach on writers’...'},
#  {'title': 'Getty Images Artificial Intelligence',
#   'url': 'https://n.news.naver.com/mnews/article/077/0006039745?sid=104',
#   'content': "This photo provided by Getty Images shows an example of the company's artificial intelligence image-generator. The Seattle-based photo stock company is taking a two-pronged approach to the threat and opportunity that AI poses to its business. On Monday, Sept. 25, 2023 it..."},
#  {'title': '금융안정에 대한 AI의 잠재적 위협과 관리 방안의 모색',
#   'url': 'http://www.ifs.or.kr/bbs/board.php?bo_table=News&wr_id=53628',
#   'content': '인공지능(Artificial Intelligence; 이하 AI) 열풍은 AI가 가져올 무한한 가능성에 대해 부푼 기대를 자아내고 있다. 금융도 AI의 활용이 빠르게 늘어나고 있는 분야이다. 특히 심층학습(deep learning) 기법을 통해 AI의 예측력이 획기적으로 고도화되면서 AI가 효율성 제고, 금융포용 확대, 소비자 만족도 개선...'},
#  {'title': '경남교육청, 교육데이터 기반 인공지능 모델·알고리즘 개발 발표',
#   'url': 'http://www.breaknews.com/989818',
#   'content': 'It is assumed that there may be errors in the English translation.> Gyeongnam Office of Education announces development of artificial intelligence model and algorithm based on education data AI teaching and learning platform, utilized in customized learning and life guidance areas The Gyeongsangnam-do...'},
#  {'title': 'The Man Who Trapped Us in Databases',
#   'url': 'https://www.nytimes.com/2023/09/22/magazine/hank-asher-data.html?partner=naver',
#   'content': 'They allow computers inside police departments, intelligence agencies, hospitals, banks, insurance companies, political parties and marketing firms to understand personal behavior and, increasingly, as artificial intelligence and machine learning expand into every corner of...'},
#  {'title': 'To Bring Socializing Back to Social Networks, Apps Try A.I. Imagery',
#   'url': 'https://www.nytimes.com/2023/09/27/technology/ai-images-social-media-sharing.html?partner=naver',
#   'content': 'Instagram, Facebook, Snapchat and several newcomers are betting on artificial intelligence to rejuvenate the fun, interactivity and whimsy of creating and sharing images. Myuri Thiruna, a freelance photographer in Toronto, used to post frequently on Instagram and discuss...'},
#  {'title': 'UN General Assembly Artificial Intelligence',
#   'url': 'https://n.news.naver.com/mnews/article/077/0006039551?sid=104',
#   'content': 'Amandeep Singh Gill, the United Nations tech policy chief, speaks during an interview with The Associated Press, Friday, Sept. 22, 2023, at U.N. headquarters. (AP Photo/Mary Altaffer)'},
#  {'title': 'European Central Bank Is Experimenting With a New Tool: A.I.',
#   'url': 'https://www.nytimes.com/2023/09/28/business/european-central-bank-artificial-intelligence.html?partner=naver',
#   'content': 'Artificial intelligence may help policymakers understand inflation and regulate big lenders, the central bank said. The European Central Bank said on Thursday that it was exploring ways to use artificial intelligence to better understand inflation and support its oversight...'}]

# %% [markdown]
# **5. Google play download ap review scraper**
#
# https://strangefate.github.io/2022/01/06/AppReview-googleplayscraper/
#
# https://github.com/JoMingyu/google-play-scraper
#
# **Google play pokemongo review**
#
# https://play.google.com/store/apps/details?id=com.nianticlabs.pokemongo&hl=en&gl=US
#
# package name: com.nianticlabs.pokemongo/ Google search: Pokémon GO - Apps on Google Play

# %%
from google_play_scraper import app

result = app(
    'com.nianticlabs.pokemongo',
    lang = 'en',
    country = 'us'
)

# %%
print(len(result))
# Out:
# 44

# %%
print(type(result))
# Out:
# <class 'dict'>

# %%
len(result['comments'])
# Out:
# 40

# %% [markdown]
# Information about the reviews

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.kakaobank.channel',
    lang = 'ko',
    country = 'kr',
    sort = Sort.NEWEST,
    count = 100,
    filter_score_with = None
)

# %%
print(len(result)) # count 개수만큼 scraping된다
# Out:
# 100

# %%
continuation_token

# %% [markdown]
# 시점을 정해서 review를 가져올 수도 있다

# %%
year = 2022
token = None
review_list = []
while year >= 2021 :
    result, continuation_token = reviews(
        'com.kakaobank.channel',
        lang = 'ko',
        country = 'kr',
        sort = Sort.NEWEST,
        continuation_token = token,
        count = 100,
        filter_score_with = None
    )
    token = continuation_token
    year = result[-1]['at'].year
    for review in result :
        if review['at'].year >= 2019 :
            temp_list = [review['score'], review['content'], review['at']]
            review_list.append(temp_list)

# %%
len(review_list)
# Out:
# 5400

# %%
review_list[-1]
# Out:
# [2,
#  '갤럭시 s20울트라사용자입니다. 최근 기기소프트웨어업데이트 후 어플실행이계속되지않네요',
#  datetime.datetime(2020, 12, 28, 10, 14, 6)]

# %% [markdown]
# Crawl all reviews

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.fantome.penguinisle',
    sleep_milliseconds = 1000,
    lang = 'en',
    country = 'us',
    sort = Sort.MOST_RELEVANT,
    filter_score_with = 5
)

# %%
result[-1]
# Out:
# {'reviewId': 'c0721745-f841-43d6-ad65-dd4b1224b734',
#  'userName': 'A Google user',
#  'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#  'content': 'Noot Noot',
#  'score': 5,
#  'thumbsUpCount': 0,
#  'reviewCreatedVersion': None,
#  'at': datetime.datetime(2019, 11, 9, 7, 53, 42),
#  'replyContent': None,
#  'repliedAt': None,
#  'appVersion': None}

# %% [markdown]
# App searching

# %%
from google_play_scraper import search

result = search(
    'best Pikachu game',
    lang = 'en',
    country = 'us',
    n_hits = 3
)

result
# Out:
# [{'appId': 'jp.pokemon.pokemonunite',
#   'icon': 'https://play-lh.googleusercontent.com/pLnno-Kti8gAEUfTTg_4StfrqyZ5Uj1uL-TfqhPsAjTQtNplljjJNgXImoRFtt8XLRw',
#   'screenshots': ['https://play-lh.googleusercontent.com/smbzF9nKSo-ZYgpf8MxlsU6nv4vjM_QRT2AIj0yYzitTufLZ6pOyZobk0MnHeG20pw',
#    'https://play-lh.googleusercontent.com/3uBfOo_EZhTE3tUIHCp63PsNffmIoUmZwY0h-mLHDIO8rRTmibhWwLVeVTRfI3guB7U',
#    'https://play-lh.googleusercontent.com/calNV6lVNiJ4br_egkr05CEw-6NeG1WKX5txFO__0I-xI4EbAZyMD-eaatVnWcfVmo4',
#    'https://play-lh.googleusercontent.com/nG_3JOo4BWuAw0ihuLcqIOsuv2pU4qJnztuk21YgzYa4pr82eZldpKxWsEbv2e09HA',
#    'https://play-lh.googleusercontent.com/2Odoh-s67q1y8tUriPT2gTg_yYnoBixMcyhXOp-iViYP8Iry-gnju0nc7_T7wAgGIic',
#    'https://play-lh.googleusercontent.com/Dbot6wLtPBuUrPnHh-dRRiIbHvMa0QHoGfxdcSNyorAigIHpXi3D9CnRRZTQGLah8A',
#    'https://play-lh.googleusercontent.com/Mw_tKBQBt2BIZhdLKtGXvqIOXpMb9PJElhNIFEDJjnI7Xz4w42WUrthFEn3hYOp-HAU',
#    'https://play-lh.googleusercontent.com/LSEtXCUpj9TG6yFQHLXfuHcFqZdMbbSVLyzhaWNLdSVgPksTSIT8F43drx5Is4tg0vo',
#    'https://play-lh.googleusercontent.com/u-o7gqspAgDCZWUbTkgbuxYF6MEIBaHfwfWAcO58PYwIJ8vHDLPI3f8OfCsYe96oKtI',
#    'https://play-lh.googleusercontent.com/I4hYjfu5nDF--0aThuLYRwb2PyugIjDe8vwbMYvb1Pa7w3xMb2yUcb3TeWHNuvOaCXDo',
#    'https://play-lh.googleusercontent.com/EZYMiKWsjXoZ425bQrXEeuzVVRsC6BV7JePVRIJTcL3VAhCbJpepVC8SjfGj4JV3vSeu',
#    'https://play-lh.googleusercontent.com/glYjavr_JW3NNOEbtw09DBMxbuFCDAsY7YFHo43Hpgv4hnud0mviJqhb4UQ7wsqxEA',
#    'https://play-lh.googleusercontent.com/T7pjZSqckBPNQLG5rdJjySYqIAu3VQ9gIbCv2UBKacSUbKQdwf3djnrHQvoz31iBTgXl',
#    'https://play-lh.googleusercontent.com/69ogaLzDBmWAzbtDSKOYZumy1qMQtu4g_e-nHP_X2KrsnGdDZcBszbt64BFpcnTnpw',
#    'https://play-lh.googleusercontent.com/LtA7oLGknq43c07K80RSVb6be9N50-JjtvOLEDf64B3JRlocg-GmlqcywXYAnnd5lCPu',
#    'https://play-lh.googleusercontent.com/N0bnn1Ey-voxf75jVWRuiy6DZkUZjhWPpXExMarytAV448ntM4x-l72CsEEyu84izA',
#    'https://play-lh.googleusercontent.com/uo5rG0DT-RIMHnoMdC6jSQ3qM3ayaqxMs4cR_bBKcFzXL2Ugln2Q4sl5QLT588xZAK8',
#    'https://play-lh.googleusercontent.com/oay4LWeP6Px8EQbXTg3abH8DDKA0wVsnhic9KER6UaaDaM1XblJUw2bi10VOxwC1SAc',
#    'https://play-lh.googleusercontent.com/nWJY6WfxK-NWG_8rZzCKRAdICqYYzc7qpKNpLJHkuLpEXZa8vEWQ9JIDvpOvAn0pUw',
#    'https://play-lh.googleusercontent.com/4unaJpXTaozuOOtSqBrKRbBlm2L3ijwaWXeRV07VNdrTlGdn77o4I8rfgBOOEY2zg3sd',
#    'https://play-lh.googleusercontent.com/GuJbJUpMOoFP3EB3ZvXXCbXrY0Ka7I-dOQJog_7fTTmKQSEXVB0cE6FHa8NDboqUnBk',
#    'https://play-lh.googleusercontent.com/kTCAe9Zg9RkHxDEm_ayLYUamY7V1VxXv5TFt6HbyfhNpuWsjNkQ5AYokxb-MNy_jkA',
#    'https://play-lh.googleusercontent.com/xaRwb8VCogFRLEqM6efU1uZABSiQSaFzuEGcOIXwPOnM94DjO67xCmLPoZtKF_ah458',
#    'https://play-lh.googleusercontent.com/NtfZkKc0kev95ptZY4KOSm4nCfXRDBT2Ky0WLdDnW1mWaqTLUS8qXAwOoQxAM30Rw_JJ',
#    'https://play-lh.googleusercontent.com/lPeKrV3QfnmjeNVM-1u6eUXxR-jamG9CbmmBr4mY0qTlaBRxz1TLHf33VhbkIPBrDQ'],
#   'title': 'Pokémon UNITE',
#   'score': 4.4124327,
#   'genre': 'Action',
#   'price': 0,
#   'free': True,
#   'currency': 'USD',
#   'video': 'https://www.youtube.com/embed/EUbBD3w9rSc?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/EUbBD3w9rSc/hqdefault.jpg',
#   'description': 'Team up and take down the opposition in Pokémon’s first 5-on-5 strategic team battle game!\r\n \r\n Join Trainers from around the world as they head for Aeos Island to compete in Unite Battles! In Unite Battles, Trainers face off in 5-on-5 team battles to see who can score the most points within the allotted time. Teamwork is key as you and your teammates defeat wild Pokémon, level up, evolve your own Pokémon, and work to prevent the opposing team from scoring points. Put your teamwork to the test, and take home the win!\r\n  \r\n Key Features:\r\n \r\n • BATTLE IN STYLE: Take to the field while looking your best in Holowear! Thanks to a special technology developed using Aeos energy, Trainers can deck out their Pokémon in a variety of holographic outfits—with new styles arriving regularly!\r\n \r\n • UNITE MOVES: Unleash the true power of your Pokémon with Unite Moves! Leverage these all-new Pokémon moves, which are only possible while in Unite Battles, and turn the tide of even the direst situations.\r\n \r\n • RANK UP: Looking to prove how skilled you are? Participate in ranked matches, and earn points as you climb up the global leaderboard!\r\n \r\n • COMMUNICATION IS KEY: Even the most-skilled Trainers recognize how important communication is to their team’s success. Leverage signals, quick-chat messages, and—for the first time in a Pokémon title—voice chat to communicate and stay in sync with your team.\r\n \r\n • CROSS-PLATFORM PLAY: Challenge Trainers from around the world to Unite Battles on the Nintendo Switch™ system or on a compatible mobile device thanks to cross-platform support. Trainers may use their Pokémon Trainer Club account or Nintendo Account on both Nintendo Switch and mobile to easily keep their progress synced between devices. \r\n \r\n Check out the official website for more information, and follow Pokémon UNITE on Twitter for all the latest news.\r\n \r\n ------------------------------------------------------------\r\n Official Website: http://PokemonUNITE.com/\r\n Official Twitter: https://twitter.com/PokemonUNITE/\r\n Terms of Use: https://www.apppokemon.com/pokemon-unite/kiyaku/kiyaku003/rule/detail/#anchor_en\r\n \r\n Legal:\r\n • This is a free-to-start game; optional in-game purchases available. Data charges may apply.\r\n • An internet connection is required to play the game.',
#   'descriptionHTML': 'Team up and take down the opposition in Pokémon’s first 5-on-5 strategic team battle game!<br> <br> Join Trainers from around the world as they head for Aeos Island to compete in Unite Battles! In Unite Battles, Trainers face off in 5-on-5 team battles to see who can score the most points within the allotted time. Teamwork is key as you and your teammates defeat wild Pokémon, level up, evolve your own Pokémon, and work to prevent the opposing team from scoring points. Put your teamwork to the test, and take home the win!<br>  <br> Key Features:<br> <br> • BATTLE IN STYLE: Take to the field while looking your best in Holowear! Thanks to a special technology developed using Aeos energy, Trainers can deck out their Pokémon in a variety of holographic outfits—with new styles arriving regularly!<br> <br> • UNITE MOVES: Unleash the true power of your Pokémon with Unite Moves! Leverage these all-new Pokémon moves, which are only possible while in Unite Battles, and turn the tide of even the direst situations.<br> <br> • RANK UP: Looking to prove how skilled you are? Participate in ranked matches, and earn points as you climb up the global leaderboard!<br> <br> • COMMUNICATION IS KEY: Even the most-skilled Trainers recognize how important communication is to their team’s success. Leverage signals, quick-chat messages, and—for the first time in a Pokémon title—voice chat to communicate and stay in sync with your team.<br> <br> • CROSS-PLATFORM PLAY: Challenge Trainers from around the world to Unite Battles on the Nintendo Switch™ system or on a compatible mobile device thanks to cross-platform support. Trainers may use their Pokémon Trainer Club account or Nintendo Account on both Nintendo Switch and mobile to easily keep their progress synced between devices. <br> <br> Check out the official website for more information, and follow Pokémon UNITE on Twitter for all the latest news.<br> <br> ------------------------------------------------------------<br> Official Website: http://PokemonUNITE.com/<br> Official Twitter: https://twitter.com/PokemonUNITE/<br> Terms of Use: https://www.apppokemon.com/pokemon-unite/kiyaku/kiyaku003/rule/detail/#anchor_en<br> <br> Legal:<br> • This is a free-to-start game; optional in-game purchases available. Data charges may apply.<br> • An internet connection is required to play the game.',
#   'developer': 'The Pokémon Company',
#   'installs': '50,000,000+'},
#  {'appId': 'com.dena.a12026418',
#   'icon': 'https://play-lh.googleusercontent.com/s5I__Gaq_Aet3BqwFyB4lnFMQGfJax7SBhzKDCTQpupswcFf11VEK21a9aZAV9QB1gE',
#   'screenshots': ['https://play-lh.googleusercontent.com/nw-je9eleL3NngrhcLw4biqi_GJWwe9PFWkmck5lJ9g8E2MXkoAK6IwUiy2Zar5nXQw',
#    'https://play-lh.googleusercontent.com/hK58LZyw76CqJ5kVkQuqwgiG1Ug9lwcsjh3nciE0emr5qMadI1_uZZxwle_V6AmKBb0',
#    'https://play-lh.googleusercontent.com/b7qRWt8DAGGlMtwtEC2QsT6SevhvriG4zxezSKL04IuGp5BpvUgRWNN1Tg75lQfAGULn',
#    'https://play-lh.googleusercontent.com/Y00bSrVYm8R6Ky0HPJHWuo2dyqnukXp3XAInoi1RMJD8c72oLwOs7vwyH7jOkSWLLq9R',
#    'https://play-lh.googleusercontent.com/n2rrP1lnEb-07le10l49Mn_01yxdz3ni_G61OOLeiQpvJFrP4Kr12uyaA1WTbJnRdJQ',
#    'https://play-lh.googleusercontent.com/-H2VmBZX2wHqGe1m86rEVyViThNHlfS_Ve--jHBmYLYetjlpJ5myc4Uq_2VOx6heTOs-',
#    'https://play-lh.googleusercontent.com/qLMhmC8MHFlWSyO7T3G0LtW1LI_5cLmJ8o3ckp4Ofq76wMK_1SlPVlp4W1PPEkWeq9Y',
#    'https://play-lh.googleusercontent.com/OIwZyp_EtELiIZwuXnFzCrCrqKQzyYQ6jULzZgV3va3stB_1gm7AF-swN0Lva3ePbAU',
#    'https://play-lh.googleusercontent.com/P6CVXDjyIdY0N2e6VCccZco41yVwK0RNEadUbdoheWNVKwEYsHFXYZ1zK8wND058iKTW',
#    'https://play-lh.googleusercontent.com/j3024cER2J5EIyNIWybWFDqfxuAkvJqrRxTKxAx55eWilRoY7aOF2JvK_yFNMm1CXAkU',
#    'https://play-lh.googleusercontent.com/22HYbUFIAT4rJ4y5asB1YQgAom1jOBQSogA8IaQbSE3H8uyJh1CS4uAC2In95pTCag'],
#   'title': 'Pokémon Masters EX',
#   'score': 4.3276854,
#   'genre': 'Role Playing',
#   'price': 0,
#   'free': True,
#   'currency': 'USD',
#   'video': 'https://www.youtube.com/embed/zMgQE8mJ-cs?ps=play&vq=large&rel=0&autohide=1&showinfo=0',
#   'videoImage': 'https://i.ytimg.com/vi/zMgQE8mJ-cs/hqdefault.jpg',
#   'description': 'TEAM UP WITH SYNC PAIRS FROM EVERY REGION!\r\nTeam up and interact with Trainers from the Hisui region, the Paldea region, and everywhere in between!\r\n\r\nTHE VILLAIN ARC CONCLUDES!\r\nPasio’s saga of villainous organizations reaches its thrilling conclusion!\r\n\r\nGET TO KNOW YOUR FAVORITE TRAINERS!\r\nInteract with Trainers in the Trainer Lodge to deepen your bond and get special photos and stories!\r\n\r\nTRAINERS DON SPECIAL OUTFITS!\r\nTrainers appear wearing outfits exclusive to Pokémon Masters EX! Enjoy original stories connected to those outfits, too!\r\n\r\nHATCH EGGS & TEAM UP!\r\nHatch Eggs to get new Pokémon! Add hatched Pokémon to your team, and battle your way to the top!\r\n\r\nENTER THE FRAY WITH A CUSTOM TEAM!\r\nAssemble Trainers and Pokémon to take on battles! Create a team all your own, and aim for victory!\r\n\r\nTRAINERS FROM ALL OVER COME TOGETHER!\r\nChampions, Elite Four members, Gym Leaders, and visitors from the past! Enjoy adventures together with your favorite Trainers and their Pokémon!\r\n\r\n\r\nNote: \r\n・We recommend a device with at least 2GB of RAM.\r\n・We do not guarantee functionality on all devices listed above.\r\n・There may be cases where the app does not function properly due to your device’s capabilities, specifications, or particular conditions for using apps.\r\n・It may take time to become compatible with the latest OS.',
#   'descriptionHTML': 'TEAM UP WITH SYNC PAIRS FROM EVERY REGION!<br>Team up and interact with Trainers from the Hisui region, the Paldea region, and everywhere in between!<br><br>THE VILLAIN ARC CONCLUDES!<br>Pasio’s saga of villainous organizations reaches its thrilling conclusion!<br><br>GET TO KNOW YOUR FAVORITE TRAINERS!<br>Interact with Trainers in the Trainer Lodge to deepen your bond and get special photos and stories!<br><br>TRAINERS DON SPECIAL OUTFITS!<br>Trainers appear wearing outfits exclusive to Pokémon Masters EX! Enjoy original stories connected to those outfits, too!<br><br>HATCH EGGS &amp; TEAM UP!<br>Hatch Eggs to get new Pokémon! Add hatched Pokémon to your team, and battle your way to the top!<br><br>ENTER THE FRAY WITH A CUSTOM TEAM!<br>Assemble Trainers and Pokémon to take on battles! Create a team all your own, and aim for victory!<br><br>TRAINERS FROM ALL OVER COME TOGETHER!<br>Champions, Elite Four members, Gym Leaders, and visitors from the past! Enjoy adventures together with your favorite Trainers and their Pokémon!<br><br><br>Note: <br>・We recommend a device with at least 2GB of RAM.<br>・We do not guarantee functionality on all devices listed above.<br>・There may be cases where the app does not function properly due to your device’s capabilities, specifications, or particular conditions for using apps.<br>・It may take time to become compatible with the latest OS.',
#   'developer': 'DeNA Co., Ltd.',
#   'installs': '10,000,000+'},
#  {'appId': 'com.pokemon.pokemonplayhouse',
#   'icon': 'https://play-lh.googleusercontent.com/YRAT4apV0ezoiTidw6hAELGWKsG6tLjtMP-el5NUOAYHvJZZFlSVub8iycILeaN5r9AR',
#   'screenshots': ['https://play-lh.googleusercontent.com/u6Km1lUaePVdG_h9rc2tmw0a_jXTXq0a3U0G9MANwlmIeAOWcOQ-ozLh4YbJH9N2LA',
#    'https://play-lh.googleusercontent.com/56CbTuY_K-uUcUO3UZsqoGvdYm23vamNEV80EXK01bwlI576pxJjPp4NfQfmK6sye_Y',
#    'https://play-lh.googleusercontent.com/ajlGHTKyUhpBDZF2lkLOwhr_c54a7hSflQ610EhpRHMFDMyM3JMeSK8wnSeWwEDU04c',
#    'https://play-lh.googleusercontent.com/FeEOo-Tu4JSk78SAWBRXJdiisB60Gkiu3GYgvOI5eBvF_DQewUUvzAydNKHAgZ_MYe6Q',
#    'https://play-lh.googleusercontent.com/Ko_DCCAzyHPA9ZnMI0PM7Vx4jULr8qWnkrRRKnSsPD-gUHRoxt7GahFhhJMwT-fvtVAL',
#    'https://play-lh.googleusercontent.com/lpzjW5nLCSQBdG9Sn4oiigGXqGr9ElNuGVXmsqbFWUNAbI18_tiQhVIs55WdB9FLJA',
#    'https://play-lh.googleusercontent.com/qHVS2JxRdIY9SfAH5w6kQRubDcmrFdPbfIf7OKSkLNEpr4qAXuXv4DNGibrTweLvQW-M',
#    'https://play-lh.googleusercontent.com/PcY9bob6Z2qhXjrT5lDf0NYgvvG8kIw5MGCeo1t3FLHGeL0Qg23ChzbzSjwH8VZ5bQ',
#    'https://play-lh.googleusercontent.com/YhX8SZ9GCRsOfEV13qMZ0QHsVaDX9ZcHa0lqPYFSAo_1YlvGZ63EMY9ilSS5Kg4Usnw',
#    'https://play-lh.googleusercontent.com/5NB9HpfRQlE8PyjYKo8U7W3cF2tFQXaDaovxp3juWUm2Wm179FCpZOPkrgnofTDGog',
#    'https://play-lh.googleusercontent.com/ZDvsoGgvx_-pMXeEKof53-n19IrhiVl9mRzDsNl6do9xsGWKSnYanFp_zFuhvI3Y5Q',
#    'https://play-lh.googleusercontent.com/ZMofMN7fFpuGZ1ZA26cT5TIrJbr1a7FNFOHvIzPWgLewXe0hW9Djz2yj9WTPoRB-Wg',
#    'https://play-lh.googleusercontent.com/hEQNbID3OOblN6lE_VwmS4YvsfaIoVw4089m7hLY8RNq3XQrRf1FdGYSHqdS3YsS9bw',
#    'https://play-lh.googleusercontent.com/wHhAxXTZ1xQL_LbxUgduswJY36tSXepwyc_d5AKsMskD4952o9HyBigs5uzW2kBlztc',
#    'https://play-lh.googleusercontent.com/M3nkxTVd92dyk8cQQXsScpQPl-Yx051kGVA-qjpefh5J6ppZyv4ZjJD9El6HYAwDYrk',
#    'https://play-lh.googleusercontent.com/oO0U41lgabxjjYPxDNveRWy-PVyQ9SGjFeq3gWh_sujGBtxfZZPtjl9ZA2ryXuyVEWI0'],
#   'title': 'Pokémon Playhouse',
#   'score': 3.142857,
#   'genre': 'Entertainment',
#   'price': 0,
#   'free': True,
#   'currency': 'USD',
#   'video': None,
#   'videoImage': None,
#   'description': 'In Pokémon Playhouse, your child can interact with all kinds of cute Pokémon as they explore various locations, including a tower, lounge, and outdoor playground. Every location within Pokémon Playhouse features activities created just for younger Pokémon fans, such as taking care of Pokémon in the Pokémon Grooming activity, or identifying Pokémon in the night sky in the Search the Stars activity. \r\n\r\nTo accompany the unique look of the Pokémon in Pokémon Playhouse, your child can watch them at play in new picture stories. Head to the Playroom to listen to a story and see the adorable Pokémon go on exciting new adventures! \r\n\r\nAt the beginning of their time in the Pokémon Playhouse, your child will be given a Pokémon Egg to keep track of. As your child explores the Pokémon Playhouse and completes activities, the Pokémon Egg will begin to hatch, and eventually reveal a new Pokémon!\r\n\r\nDesigned for children ages 3–5, no reading or math skills are necessary to complete activities. A friendly human character will host and narrate all the activities so your child can enjoy every aspect of the Pokémon Playhouse regardless of their learning level.\r\n\r\nThe Pokémon Playhouse app does not collect any personal information and does not include any in-app purchases.\r\n\r\nDownload the app for free and let your child start exploring the wonderful Pokémon Playhouse today!',
#   'descriptionHTML': 'In Pokémon Playhouse, your child can interact with all kinds of cute Pokémon as they explore various locations, including a tower, lounge, and outdoor playground. Every location within Pokémon Playhouse features activities created just for younger Pokémon fans, such as taking care of Pokémon in the Pokémon Grooming activity, or identifying Pokémon in the night sky in the Search the Stars activity. <br><br>To accompany the unique look of the Pokémon in Pokémon Playhouse, your child can watch them at play in new picture stories. Head to the Playroom to listen to a story and see the adorable Pokémon go on exciting new adventures! <br><br>At the beginning of their time in the Pokémon Playhouse, your child will be given a Pokémon Egg to keep track of. As your child explores the Pokémon Playhouse and completes activities, the Pokémon Egg will begin to hatch, and eventually reveal a new Pokémon!<br><br>Designed for children ages 3–5, no reading or math skills are necessary to complete activities. A friendly human character will host and narrate all the activities so your child can enjoy every aspect of the Pokémon Playhouse regardless of their learning level.<br><br>The Pokémon Playhouse app does not collect any personal information and does not include any in-app purchases.<br><br>Download the app for free and let your child start exploring the wonderful Pokémon Playhouse today!',
#   'developer': 'The Pokémon Company International',
#   'installs': '5,000,000+'}]
