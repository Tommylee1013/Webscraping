# %% [markdown]
# ### Feature preprocessing

# %% [markdown]
# #### FinBERT Score

# %%
import pandas as pd
import numpy as np

fd_speech = pd.read_csv('../../Data/Final/federal_sentiment.csv', index_col = 0)
fd_speech.index = pd.to_datetime(fd_speech.index).strftime('%Y-%m')
fd_speech.index = pd.to_datetime(fd_speech.index)

fd_press = pd.read_csv('../../Data/Final/press_sentiment.csv', index_col = 0)
fd_press.index = pd.to_datetime(fd_press.index).strftime('%Y-%m')
fd_press.index = pd.to_datetime(fd_press.index)

invest_com = pd.read_csv('../../Data/Final/invest_com_sentiment.csv', index_col = 0)
invest_com.index = pd.to_datetime(invest_com.index).strftime('%Y-%m')

usdt = pd.read_csv('../../Data/Final/USDT_sentiment.csv', index_col = 0)
usdt.index = pd.to_datetime(usdt.index).strftime('%Y-%m')

ft = pd.read_csv('../../Data/Final/ft_sentiment.csv', index_col = 0)
ft.index = pd.to_datetime(ft.index).strftime('%Y-%m')

# %%
fd_press
# Out:
#             Negative   Neutral  sentimental_score
# Date
# 2006-01-01  0.997587  0.001521          -0.995934
# 2006-02-01  0.995709  0.000902          -0.991869
# 2006-03-01  0.924128  0.075699          -0.886105
# 2006-04-01  0.950914  0.000196          -0.901927
# 2006-05-01  0.911347  0.088517          -0.866952
# ...              ...       ...                ...
# 2023-07-01  0.811841  0.001076          -0.624220
# 2023-08-01  0.904288  0.054327          -0.835740
# 2023-09-01  0.988094  0.011596          -0.981985
# 2023-10-01  0.998002  0.000656          -0.996331
# 2023-11-01  0.979247  0.020530          -0.968760
#
# [215 rows x 3 columns]

# %%
invest_com
# Out:
#          Positive  Negative   Neutral  sentimental_score
# Date
# 2023-11  0.159651  0.646914  0.193435          -0.390545
# 2023-10  0.160515  0.635881  0.203604          -0.373564
# 2023-09  0.151963  0.656168  0.191869          -0.408270
# 2023-08  0.122717  0.711143  0.166141          -0.505356
# 2023-07  0.103711  0.745990  0.150299          -0.567130
# 2023-06  0.094562  0.734463  0.170975          -0.554413
# 2023-05  0.138747  0.724805  0.136448          -0.517834
# 2023-04  0.130142  0.714174  0.155683          -0.506190
# 2023-03  0.131547  0.734119  0.134333          -0.535405
# 2023-02  0.083283  0.775285  0.141431          -0.621286
# 2023-01  0.113265  0.743193  0.143542          -0.558157
# 2022-12  0.122348  0.727467  0.150185          -0.530027
# 2022-11  0.122920  0.733155  0.143925          -0.538273
# 2022-10  0.133871  0.711609  0.154520          -0.500479
# 2022-09  0.120112  0.719561  0.160327          -0.519286
# 2022-08  0.119312  0.718504  0.162184          -0.518100
# 2022-07  0.140451  0.689566  0.169983          -0.464124
# 2022-06  0.119699  0.738483  0.141818          -0.547874
# 2022-05  0.109284  0.713173  0.177543          -0.515118
# 2022-04  0.114747  0.731923  0.153330          -0.540511
# 2022-03  0.124584  0.761502  0.113914          -0.579961
# 2022-02  0.090664  0.771379  0.137957          -0.611737
# 2022-01  0.093653  0.724971  0.181376          -0.540630
# 2021-12  0.075194  0.757125  0.167681          -0.598091
# 2021-11  0.078778  0.777119  0.144103          -0.626290

# %%
ft
# Out:
#          Positive  Negative   Neutral  sentimental_score
# Date
# 2023-11  0.174408  0.688674  0.136918          -0.445808
# 2023-10  0.241055  0.525816  0.233129          -0.168197
# 2023-09  0.224177  0.573975  0.201848          -0.248874
# 2023-08  0.144376  0.757819  0.097805          -0.564540
# 2023-07  0.298952  0.569860  0.131188          -0.205313
# 2023-06  0.085023  0.727201  0.187776          -0.548289
# 2023-05  0.242027  0.627649  0.130324          -0.320459
# 2023-04  0.289253  0.593404  0.117343          -0.245479
# 2023-03  0.262735  0.627765  0.109500          -0.310280
# 2023-02  0.186114  0.635836  0.178050          -0.360697
# 2023-01  0.099978  0.587200  0.312822          -0.330811
# 2022-12  0.203554  0.589863  0.206583          -0.283018
# 2022-11  0.234410  0.545349  0.220240          -0.200819
# 2022-10  0.200804  0.672526  0.126670          -0.408388
# 2022-09  0.199042  0.637858  0.163100          -0.357267
# 2022-08  0.203809  0.645549  0.150641          -0.366419
# 2022-07  0.283156  0.527786  0.189058          -0.150100
# 2022-06  0.270299  0.567947  0.161753          -0.216771
# 2022-05  0.154391  0.758516  0.087093          -0.560578
# 2022-04  0.117450  0.773610  0.108940          -0.601690
# 2022-03  0.249807  0.557184  0.193009          -0.210872
# 2022-02  0.143109  0.725116  0.131776          -0.516119
# 2022-01  0.184032  0.684803  0.131164          -0.435189
# 2021-12  0.156116  0.753452  0.090432          -0.552119
# 2021-11  0.207745  0.665200  0.127056          -0.393927
# 2021-10  0.176380  0.705675  0.117946          -0.470322
# 2021-09  0.215501  0.646039  0.138460          -0.361308
# 2021-08  0.124789  0.660259  0.214952          -0.427994
# 2021-07  0.157800  0.689560  0.152640          -0.455440
# 2021-06  0.145355  0.748378  0.106268          -0.549889
# 2021-05  0.118462  0.795748  0.085789          -0.634392
# 2021-04  0.208625  0.593957  0.197418          -0.286623
# 2021-03  0.089211  0.717830  0.192959          -0.532140
# 2021-02  0.202181  0.606202  0.191617          -0.308212
# 2021-01  0.305763  0.692176  0.002061          -0.385383
# 2020-12  0.119055  0.737268  0.143677          -0.546374
# 2020-11  0.178871  0.752938  0.068191          -0.539971
# 2020-10  0.175156  0.748806  0.076037          -0.535632
# 2020-09  0.131790  0.819864  0.048346          -0.663901
# 2020-08  0.281896  0.624814  0.093290          -0.296273
# 2020-07  0.120421  0.753881  0.125698          -0.570612
# 2020-06  0.168726  0.710329  0.120945          -0.481130
# 2020-05  0.249296  0.496663  0.254041          -0.120346
# 2020-04  0.134044  0.687118  0.178838          -0.463656
# 2020-03  0.155356  0.683940  0.160703          -0.448232
# 2020-02  0.073606  0.628408  0.297986          -0.405809
# 2020-01  0.148903  0.675774  0.175323          -0.439210
# 2019-12  0.152910  0.691829  0.155260          -0.461289
# 2019-11  0.155964  0.613831  0.230205          -0.342764
# 2019-10  0.229948  0.619001  0.151052          -0.313527
# 2019-09  0.214123  0.606583  0.179293          -0.302813
# 2019-08  0.215622  0.677417  0.106960          -0.408315
# 2019-07  0.064060  0.790115  0.145825          -0.653142
# 2019-06  0.135557  0.734414  0.130029          -0.533843
# 2019-05  0.266043  0.571977  0.161980          -0.224943
# 2019-04  0.138558  0.755921  0.105520          -0.564603
# 2019-03  0.167230  0.632296  0.200474          -0.364828
# 2019-02  0.137491  0.626814  0.235695          -0.371475
# 2019-01  0.102436  0.701169  0.196395          -0.500535
# 2018-12  0.234367  0.633257  0.132375          -0.332702

# %%
sum_mat = usdt.add(invest_com, fill_value = 0).add(ft, fill_value = 0)

# %%
sum_mat.index = pd.to_datetime(sum_mat.index)

# %%
sum_mat.loc['2021-11' : ] = sum_mat.loc['2021-11' : ]/3

# %%
sum_mat.loc['2018-12' : '2021-10'] =  sum_mat.loc['2018-12' : '2021-10'] / 2

# %%
import matplotlib.pyplot as plt
plt.hist(sum_mat.sentimental_score, bins = 100)
plt.grid(False)
plt.show()

# %%
plt.plot(sum_mat.sentimental_score)

# %%
plt.hist(fd_press.sentimental_score, bins = 100)
plt.grid(False)
plt.show()

# %%
plt.plot(fd_press.sentimental_score)

# %%
plt.hist(fd_speech.sentimental_score, bins = 100)
plt.grid(False)
plt.show()

# %%
plt.plot(fd_speech.sentimental_score)

# %% [markdown]
# #### GDP Data

# %%
gdp = pd.read_csv('../../Data/GDP.csv',index_col = 0)
gdp.index = pd.to_datetime(gdp.index).strftime('%Y-%m')
gdp.index = pd.to_datetime(gdp.index)
gdp
# Out:
#                   GDP
# DATE
# 2004-01-01  11923.447
# 2004-04-01  12112.815
# 2004-07-01  12305.307
# 2004-10-01  12527.214
# 2005-01-01  12767.286
# ...               ...
# 2022-07-01  25994.639
# 2022-10-01  26408.405
# 2023-01-01  26813.601
# 2023-04-01  27063.012
# 2023-07-01  27623.543
#
# [79 rows x 1 columns]

# %%
cpi = pd.read_csv('../../Data/CPIAUCSL.csv',index_col = 0)
cpi.index = pd.to_datetime(cpi.index).strftime('%Y-%m')
cpi.index = pd.to_datetime(cpi.index)
cpi
# Out:
#             CPIAUCSL
# DATE
# 2004-01-01   186.300
# 2004-02-01   186.700
# 2004-03-01   187.100
# 2004-04-01   187.400
# 2004-05-01   188.200
# ...              ...
# 2023-06-01   303.841
# 2023-07-01   304.348
# 2023-08-01   306.269
# 2023-09-01   307.481
# 2023-10-01   307.619
#
# [238 rows x 1 columns]

# %%
gdp_rate = np.log(gdp / gdp.shift(4)).dropna()
cpi_rate = np.log(cpi / cpi.shift(12)).dropna()

# %%
import matplotlib.pyplot as plt
plt.plot(gdp_rate)
plt.plot(cpi_rate)
plt.grid(False)

# %% [markdown]
# GDP 결측치 : proportional denton method

# %%
from statsmodels.tsa.interp.denton import dentonm

benchmarked = dentonm(cpi_rate.cumsum(), gdp_rate.cumsum(), freq = "qm")

# %%
plt.plot(pd.Series(benchmarked * 3, index = cpi_rate.index))
plt.plot(gdp_rate.cumsum())
plt.grid(False)

# %%
target_gdp = (pd.Series(benchmarked, index = cpi_rate.index) - pd.Series(benchmarked, index = cpi_rate.index).shift(1)).dropna() * 3
target_gdp.index = target_gdp.index.strftime('%Y-%m')
target_gdp.index = pd.to_datetime(target_gdp.index)

# %%
plt.plot(target_gdp, label = 'Denton method GDP rate')
plt.plot(gdp_rate / 3, label = 'Real GDP rate')
plt.legend()
plt.grid(False)
plt.show()

# %%
from statsmodels.tsa.statespace.mlemodel import MLEModel

def kalman_smoothing(close : pd.Series, 
                     q : float, dt : float = 1.0, s : float = 0.5,
                     A : np.array = np.array([[1]]), 
                     Q : np.array = np.array([[1]]), 
                     H : np.array = np.array([[1]]), 
                     R : np.array = np.eye(1),
                     m0 : np.array = np.array([[1]]),
                     P0 : np.array = np.eye(1),
                     k_state : int = 1) -> pd.DataFrame :
    Q = q * Q
    R = s ** 2 * R

    kf = MLEModel(close, k_states = k_state)
    kf._state_names = ['x1']
    kf['design'] = H
    kf['obs_cov'] = R
    kf['transition'] = A
    kf['selection'] = np.eye(1)
    kf['state_cov'] = Q

    kf.initialize_known(A @ m0[:, 0], A @ P0 @ A.T + Q)
    res = kf.smooth(params = [])
    output = pd.DataFrame(res.states.smoothed.x1.values, index = close.index, columns = ['smoothered'])
    
    return output

# %%
kalman_smoothed = kalman_smoothing(target_gdp.cumsum(), q = 0.1)
# Out:
# /Users/junghunlee/anaconda3/envs/Webscraping/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
gdp_target = kalman_smoothed.diff()

# %%
plt.plot(target_gdp, label = 'Denton method GDP rate')
plt.plot(gdp_target, label = 'kalman_smoothed')
plt.plot(gdp_rate / 3, label = 'Real GDP rate')
plt.legend()
plt.grid(False)
plt.show()

# %% [markdown]
# #### Federal Funds Rate

# %%
ffr = pd.read_csv('../../Data/DFF.csv', index_col = 0) * 0.01
ffr.index = pd.to_datetime(ffr.index)
ffr = ffr.resample('M').mean()
ffr.index = ffr.index.strftime('%Y-%m')
ffr.index = pd.to_datetime(ffr.index)
ffr
# Out:
#                  DFF
# DATE
# 2005-01-01  0.022794
# 2005-02-01  0.025018
# 2005-03-01  0.026290
# 2005-04-01  0.027850
# 2005-05-01  0.030026
# ...              ...
# 2023-07-01  0.051200
# 2023-08-01  0.053300
# 2023-09-01  0.053300
# 2023-10-01  0.053300
# 2023-11-01  0.053300
#
# [227 rows x 1 columns]

# %% [markdown]
# #### Unemployment Rate

# %%
unemploy = pd.read_csv('../../Data/UNRATE.csv', index_col = 0) * 0.01
unemploy.index = pd.to_datetime(unemploy.index).strftime('%Y-%m')
unemploy.index = pd.to_datetime(unemploy.index)
unemploy
# Out:
#             UNRATE
# DATE
# 2005-01-01   0.053
# 2005-02-01   0.054
# 2005-03-01   0.052
# 2005-04-01   0.052
# 2005-05-01   0.051
# ...            ...
# 2023-06-01   0.036
# 2023-07-01   0.035
# 2023-08-01   0.038
# 2023-09-01   0.038
# 2023-10-01   0.039
#
# [226 rows x 1 columns]

# %%
plt.plot(gdp_target, label = 'kalman smoothed GDP rate')
plt.plot(gdp_rate / 3, label = 'Real GDP rate')
plt.plot(unemploy, label = 'unemployment rate')
plt.plot(ffr, label = 'Federal funds rate')
plt.plot(cpi_rate, label = 'CPI rate')
plt.legend()
#(sentiment['sentimental_score'] * 0.1).plot(label = 'federal sentiment score')
plt.grid(False)
plt.show()

# %%
fd_speech
# Out:
#                 Positive      Negative   Neutral  sentimental_score
# Date
# 2006-01-01  7.971052e-08  2.516444e-07  1.000000           0.500000
# 2006-02-01  2.134020e-01  4.994306e-01  0.287167          -0.142445
# 2006-03-01  2.156177e-01  5.577889e-01  0.226593          -0.228875
# 2006-04-01  4.671889e-02  4.433666e-01  0.509914          -0.141691
# 2006-05-01  1.709526e-04  6.226610e-01  0.377168          -0.433906
# ...                  ...           ...       ...                ...
# 2023-07-01  5.476058e-02  6.210716e-01  0.324168          -0.404227
# 2023-08-01  5.046593e-04  7.823840e-01  0.217111          -0.673324
# 2023-09-01  1.012808e-03  6.145024e-01  0.384485          -0.421247
# 2023-10-01  2.448585e-03  7.261041e-01  0.271447          -0.587932
# 2023-11-01  1.255554e-04  6.861930e-01  0.313681          -0.529227
#
# [215 rows x 4 columns]

# %%
feature_matrix = pd.concat(
    [
        fd_speech['sentimental_score'],
        fd_press['sentimental_score'],
        sum_mat['sentimental_score'].fillna(method = 'ffill'),
        ffr,
        cpi_rate,
        unemploy,
        target_gdp
    ],
    axis = 1
)

feature_matrix.columns = ['FED_sentiment','press_sentiment','news_sentiment','federal_funds_rate','cpi','unemployment_rate','gdp_rate']

# %%
feature_matrix.dropna(inplace = True)
feature_matrix.index = pd.to_datetime(feature_matrix.index)

# %%
feature_matrix
# Out:
#             FED_sentiment  press_sentiment  news_sentiment  \
# 2008-01-01      -0.133390        -0.998301       -0.498668
# 2008-02-01      -0.036268        -0.977886       -0.363908
# 2008-03-01      -0.224101        -0.890550       -0.399844
# 2008-04-01      -0.112347        -0.979160       -0.018012
# 2008-05-01      -0.073838        -0.998644       -0.914042
# ...                   ...              ...             ...
# 2023-06-01      -0.277175        -0.984316       -0.576140
# 2023-07-01      -0.404227        -0.624220       -0.373797
# 2023-08-01      -0.673324        -0.835740       -0.484305
# 2023-09-01      -0.421247        -0.981985       -0.291875
# 2023-10-01      -0.587932        -0.996331       -0.384316
#
#             federal_funds_rate       cpi  unemployment_rate  gdp_rate
# 2008-01-01            0.039403  0.042050              0.050  0.009511
# 2008-02-01            0.029807  0.040594              0.049  0.009839
# 2008-03-01            0.026103  0.038979              0.051  0.010456
# 2008-04-01            0.022783  0.038295              0.050  0.011985
# 2008-05-01            0.019784  0.040070              0.054  0.009317
# ...                        ...       ...                ...       ...
# 2023-06-01            0.050763  0.030452              0.036  0.016487
# 2023-07-01            0.051200  0.032458              0.035  0.021374
# 2023-08-01            0.053300  0.036404              0.038  0.022623
# 2023-09-01            0.053300  0.036235              0.038  0.021522
# 2023-10-01            0.053300  0.031812              0.039  0.017989
#
# [184 rows x 7 columns]

# %% [markdown]
# #### RandomForest Regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc

# %%
X = feature_matrix.iloc[:,:3]
y = feature_matrix['gdp_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05, shuffle = False, random_state = 42)

randomforest_reg = RandomForestRegressor(n_estimators = 1000,
                                         random_state = 42,
                                         criterion = 'absolute_error',
                                         ccp_alpha = 0.0001)
randomforest_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(ccp_alpha=0.0001, criterion='absolute_error',
#                       n_estimators=1000, random_state=42)

# %%
from sklearn.metrics import mean_squared_error
y_pred = randomforest_reg.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 6.108310788008784e-05

# %%
import seaborn as sns

beta, alpha = np.polyfit(x = y_test, y = y_pred , deg = 1)
#plt.axvline(0, color = 'grey', alpha = 0.5)
#plt.axhline(0, color = 'grey', alpha = 0.5)
sns.scatterplot(x = y_test , y = y_pred , label = 'Returns')
sns.lineplot(x = y_test, y = alpha + y_test * beta, color = 'red', label = 'Fitted Line', alpha = 0.7)
plt.legend(loc = 'center left', bbox_to_anchor = (1, 0.5))
plt.grid(False)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('prediction versus actual', fontfamily = 'Serif')
plt.show()

# %%
import shap

explainer_randomforest_reg = shap.TreeExplainer(randomforest_reg)

shap_values_train = explainer_randomforest_reg(X_train)
shap_values_test = explainer_randomforest_reg(X_test)
shap_values_all = explainer_randomforest_reg(X)

# %%
plt.grid(False)
shap.plots.beeswarm(shap_values_train)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
plt.grid(False)
shap.plots.beeswarm(shap_values_test)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
plt.plot(pd.Series(y_pred, index = y_test.index[-len(y_pred):]) + 0.005, label = 'forecast')
plt.plot(feature_matrix['gdp_rate'].loc['2022':], label = 'test')
plt.plot(gdp_rate.loc['2022':] / 3, label = 'real data')
plt.grid(False)
plt.legend()
plt.title('GDP forecast', fontsize = 12, fontfamily = 'Serif')
# Out:
# Text(0.5, 1.0, 'GDP forecast')

# %%
plt.figure(figsize = (10, 4))
plt.plot(pd.Series(y_pred, index = y_test.index[-len(y_pred):])*1.5, label = 'forecast')
plt.plot(feature_matrix['gdp_rate'], label = 'test')
plt.plot(gdp_rate / 3, label = 'real data')
plt.plot(pd.Series(
    randomforest_reg.predict(X_train),
    index = X_train.index
), 
         label = 'train data')
plt.grid(False)
plt.legend()
plt.title('GDP forecast', fontsize = 12, fontfamily = 'Serif')
# Out:
# Text(0.5, 1.0, 'GDP forecast')
